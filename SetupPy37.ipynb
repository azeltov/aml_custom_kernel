# %%
CONDA_ENV_NAME = 'py37'
KERNEL_DISPLAY_NAME = 'AzureML - Py37'

# %%
# %conda create --name {CONDA_ENV_NAME}  python=3.7 -y
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/py37
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.4.5.1         |           py37_0         159 KB
#     pip-20.0.2                 |           py37_1         1.9 MB
#     python-3.7.7               |hcf32534_0_cpython        52.5 MB
#     readline-8.0               |       h7b6447c_0         428 KB
#     wheel-0.34.2               |           py37_0          49 KB
#     sqlite-3.31.1              |       h7b6447c_0         2.0 MB
#     ncurses-6.2                |       he6710b0_0         1.1 MB
# ...

# %%
# %conda install -n {CONDA_ENV_NAME} ipykernel -y
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/py37
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     prompt-toolkit-3.0.4       |             py_0         240 KB
#     entrypoints-0.3            |           py37_0          12 KB
#     prompt_toolkit-3.0.4       |                0          11 KB
#     jupyter_core-4.6.3         |           py37_0          75 KB
#     tornado-6.0.4              |   py37h7b6447c_1         649 KB
#     decorator-4.4.2            |             py_0          14 KB
#     jupyter_client-6.1.2       |             py_0          81 KB
# ...

# %%
# !/anaconda/envs/{CONDA_ENV_NAME}/bin/python -m ipykernel install --user --name {CONDA_ENV_NAME} --display-name "{KERNEL_DISPLAY_NAME}"
# Out:
# Installed kernelspec py37 in /home/azureuser/.local/share/jupyter/kernels/py37
